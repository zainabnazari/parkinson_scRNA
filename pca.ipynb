# %%
import os
import scanpy as sc
import pandas as pd

# %%
 adata = sc.read_h5ad('/projects/bioinformatics/DB/scRNAseq_parkinson/metadata.csv')

# %%
adata = sc.read_h5ad("your_data.h5ad")  # replace with your file

# 1. Normalize the data
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# 2. Identify highly variable genes (HVGs)
sc.pp.highly_variable_genes(adata, n_top_genes=2000, flavor='seurat')
adata_hvg = adata[:, adata.var.highly_variable]

# 3. Scale the data (zero mean, unit variance)
sc.pp.scale(adata_hvg)

# 4. Compute PCA
sc.tl.pca(adata_hvg, svd_solver='arpack')

# 5. Visualize PCA colored by Leiden clusters or cell type
sc.pl.pca_scatter(adata_hvg, color=['cell_type'])
