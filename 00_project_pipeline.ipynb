# %% [markdown]
# # Project Pipeline
# ### Description
# This notebook summarize the full analysis workflow and links to the project
#
# ### Created: 2026-01-14

# %% [markdown]
# # 01_data_overview.ipynb

# %% [markdown]
# The general overview of the data of scRNA seq Parkinson disease

# %% [markdown]
# # 02_analysis_baseline_pca.ipynb

# %% [markdown]
# Here is the baseline analysis is done, high value genes are selected, PCA is computed, clustering is done and nmi is computed

# %% [markdown]
# # 03_embedding_scvi.ipynb

# %% [markdown]
# Here scvi embedding is computed and umap is plotted

# %% [markdown]
# # 03_resolution_scvi.ipynb

# %% [markdown]
# Here the clustering based on the scvi embedding is done, nmi is computed

# %% [markdown]
# # 04_embedding_geneformer.ipynb

# %% [markdown]
# Here geneformer embedding is computed and umap is plotted

# %% [markdown]
# # 04_resolution_geneformer.ipynb

# %% [markdown]
# Here the clustering based on the geneformer embedding is done, nmi is computed

# %% [markdown]
# # 05_celltype_baseline_pca.ipynb

# %% [markdown]
# Here NMI for baselie is computed based on the each cell types with regrard to disease and control

# %% [markdown]
# # 05_celltype_disease_scvi.ipynb

# %% [markdown]
# Here NMI for scvi is computed based on the each cell types with regrard to disease and control

# %% [markdown]
# # 05_celltype_geneformer.ipynb

# %% [markdown]
# Here NMI for geneformer is computed based on the each cell types with regrard to disease and control

# %% [markdown]
# ### Late updated: 2026-03-19
