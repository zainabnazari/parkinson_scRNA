# %%
import os
import scanpy as sc
import anndata as ad
import pandas as pd
import time 
import numpy as np
import liana as li
import itertools

import scipy as sci
from scipy.stats import false_discovery_control

# %%
adata = sc.read_h5ad('/projects/bioinformatics/DB/scRNAseq_parkinson/dataset.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2096155 × 17267
#     obs: 'n_genes', 'n_counts', 'Brain_bank', 'RIN', 'path_braak_lb', 'derived_class2', 'PMI', 'tissue_ontology_term_id', 'tissue_type', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'suspension_type', 'is_primary_data', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'gene_name', 'n_cells', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'batch_condition', 'citation', 'genome', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title', 'uid'
#     obsm: 'X_umap'

# %%
lr_resource = pd.read_csv("/projects/bioinformatics/DB/CellCellCommunication/WithEnzymes/cpdb_cellchat_enz_liana_format.csv")

# %%
# we need to make sure that genes are not in the complex form but seperated G1 and G2
lr_resource[:800]
# Out:
#            ligand              receptor
# 0            CDH1           ITGA2_ITGB1
# 1            CDH1           ITGAE_ITGB7
# 2            CDH1                 KLRG1
# 3            CDH2                  CDH2
# 4            CDH2                 FCER2
# ..            ...                   ...
# 795  GAD1+SLC32A1  GABRA2_GABRB3_GABRG2
# 796  GAD1+SLC32A1   GABRA3_GABRB3_GABRE
# 797  GAD1+SLC32A1  GABRA3_GABRB3_GABRG2
# 798  GAD1+SLC32A1   GABRA3_GABRB3_GABRQ
# 799  GAD1+SLC32A1   GABRA4_GABRB2_GABRD
#
# [800 rows x 2 columns]

# %%
# here we split them 
import re

def split_genes(gene_entry):
    if pd.isna(gene_entry):
        return []
    
    # split on BOTH "_" and "+"
    genes = re.split(r"[+_]", str(gene_entry))
    
    # remove empty strings if any
    return [g for g in genes if g]

# %%
ligand_genes = lr_resource["ligand"].apply(split_genes)
receptor_genes = lr_resource["receptor"].apply(split_genes)

all_genes = set(itertools.chain.from_iterable(ligand_genes)) | \
            set(itertools.chain.from_iterable(receptor_genes))

print("Total unique LR genes:", len(all_genes))
# Out:
# Total unique LR genes: 1576

# %%
all_genes;

# %%
print(adata.var_names[:20])
# Out:
# Index(['ENSG00000186827', 'ENSG00000186891', 'ENSG00000160072',
#        'ENSG00000041988', 'ENSG00000142611', 'ENSG00000067606',
#        'ENSG00000131584', 'ENSG00000169972', 'ENSG00000157911',
#        'ENSG00000224051', 'ENSG00000157933', 'ENSG00000162591',
#        'ENSG00000169962', 'ENSG00000116285', 'ENSG00000142655',
#        'ENSG00000149527', 'ENSG00000007923', 'ENSG00000171621',
#        'ENSG00000162441', 'ENSG00000187017'],
#       dtype='object', name='gene_id')

# %%
print(adata.var.head())
# Out:
#                 gene_name  n_cells  feature_is_filtered feature_name  \
# gene_id
# ENSG00000186827   TNFRSF4     7846                False      TNFRSF4
# ENSG00000186891  TNFRSF18     9000                False     TNFRSF18
# ENSG00000160072    ATAD3B   340777                False       ATAD3B
# ENSG00000041988     THAP3   209923                False        THAP3
# ENSG00000142611    PRDM16   283396                False       PRDM16
#
#                 feature_reference feature_biotype feature_length  \
# gene_id
# ENSG00000186827    NCBITaxon:9606            gene           1039
# ENSG00000186891    NCBITaxon:9606            gene            789
# ENSG00000160072    NCBITaxon:9606            gene           3300
# ENSG00000041988    NCBITaxon:9606            gene            931
# ENSG00000142611    NCBITaxon:9606            gene           3730
#
#                    feature_type
# gene_id
# ENSG00000186827  protein_coding
# ENSG00000186891  protein_coding
# ENSG00000160072  protein_coding
# ENSG00000041988  protein_coding
# ENSG00000142611  protein_coding

# %%
# Set gene symbols as var_names

adata.var_names = adata.var["gene_name"]
# Out:
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:835: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['TNFRSF4', 'TNFRSF18', 'ATAD3B', 'THAP3', 'PRDM16']
#
#     Inferred to be: categorical

# %%
# to fix warning 
adata.var_names = adata.var["gene_name"].astype(str)

# %%
adata.var_names_make_unique()

# %%
print(adata.var_names[:10])
print(type(adata.var_names[0]))
# Out:
# Index(['TNFRSF4', 'TNFRSF18', 'ATAD3B', 'THAP3', 'PRDM16', 'PRKCZ', 'ACAP3',
#        'PUSL1', 'PEX10', 'CPTP'],
#       dtype='object', name='gene_name')
# <class 'str'>

# %%
genes_in_data = list(set(adata.var_names) & all_genes)

print("Genes found in dataset:", len(genes_in_data))
# Out:
# Genes found in dataset: 1415

# %%
# subset 
start = time.time()
adata_lr = adata[:, genes_in_data].copy()
print(adata_lr.shape)
end = time.time()
timing = end - start
print(f'timing:{timing:.2f}second')
# Out:
# (2096155, 1415)
# timing:206.14second

# %%
start = time.time()

results = li.method.cellphonedb(
    adata_lr,
    groupby="cell_type",
    resource=lr_resource,
    use_raw=False
)
end = time.time()
timing = end - start
print(f'timing:{timing:.2f}second')
# Out:
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:381: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:149: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# timing:7519.03second

# %%
start = time.time()
res = li.method.cellphonedb.by_sample(
    adata,
    groupby="cell_type",
    sample_key="disease",   
    resource=lr_resource,
    use_raw=False
)

end = time.time()
timing = end - start
print(f'timing:{timing:.2f}second')
# Out:
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:381: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:146: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:149: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:381: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:146: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# /home/znazari/.conda/envs/liana_scanpy/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:149: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# timing:6249.02second

# %%
print(adata.uns.keys())
# Out:
# dict_keys(['batch_condition', 'citation', 'genome', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title', 'uid', 'liana_res'])

# %%
res1 = adata.uns["liana_res"]

# %%
type(res1)
# Out:
# pandas.core.frame.DataFrame

# %%
res1.to_csv("/projects/bioinformatics/DB/scRNAseq_parkinson/liana_results_sample.csv", index=False)

# %%
res1 = pd.read_csv("/projects/bioinformatics/DB/scRNAseq_parkinson/liana_results_sample.csv")

# %%
res1
# Out:
#                  disease  ligand ligand_complex  ligand_means  ligand_props  \
# 0                 normal   NLGN1          NLGN1      5.963885      0.999125
# 1                 normal   NLGN1          NLGN1      5.963885      0.999125
# 2                 normal  LRRTM4         LRRTM4      5.563381      0.997374
# 3                 normal   NLGN1          NLGN1      5.963885      0.999125
# 4                 normal    NRG3           NRG3      6.036231      0.998887
# ...                  ...     ...            ...           ...           ...
# 65251  Parkinson disease      C5             C5      0.165941      0.103910
# 65252  Parkinson disease   WNT8A          WNT8A      0.156221      0.103258
# 65253  Parkinson disease     PYY            PYY      0.170627      0.112251
# 65254  Parkinson disease   HLA-A          HLA-A      0.175738      0.106003
# 65255  Parkinson disease   WNT8A          WNT8A      0.156221      0.103258
#
#       receptor receptor_complex  receptor_means  receptor_props  \
# 0        NRXN3            NRXN3        6.199426        0.999746
# 1        NRXN1            NRXN1        5.933232        0.999083
# 2        NRXN3            NRXN3        6.199426        0.999746
# 3        NRXN1            NRXN1        5.689255        0.999367
# 4        ERBB4            ERBB4        5.509386        0.921737
# ...        ...              ...             ...             ...
# 65251    C5AR1            C5AR1        0.177606        0.111052
# 65252    SFRP1            SFRP1        0.187223        0.102392
# 65253    NPY5R            NPY5R        0.168829        0.108387
# 65254     CD8A             CD8A        0.160177        0.102710
# 65255     FZD4        FZD4_LRP6        0.160458        0.108187
#
#                                source                          target  \
# 0      oligodendrocyte precursor cell                GABAergic neuron
# 1      oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 2      oligodendrocyte precursor cell                GABAergic neuron
# 3      oligodendrocyte precursor cell            glutamatergic neuron
# 4                           astrocyte                GABAergic neuron
# ...                               ...                             ...
# 65251            glutamatergic neuron   central nervous system neuron
# 65252   central nervous system neuron   central nervous system neuron
# 65253   central nervous system neuron   central nervous system neuron
# 65254            glutamatergic neuron            glutamatergic neuron
# 65255   central nervous system neuron   central nervous system neuron
#
#        lr_means  cellphone_pvals
# 0      6.081656              0.0
# 1      5.948559              0.0
# 2      5.881403              0.0
# 3      5.826570              0.0
# 4      5.772809              0.0
# ...         ...              ...
# 65251  0.171773              1.0
# 65252  0.171722              0.0
# 65253  0.169728              0.0
# 65254  0.167958              1.0
# 65255  0.158340              0.0
#
# [65256 rows x 13 columns]

# %%
adata_lr.obs["cell_type"].value_counts()
# Out:
# cell_type
# oligodendrocyte                      1093520
# glutamatergic neuron                  328856
# astrocyte                             227452
# GABAergic neuron                      152393
# central nervous system macrophage     118515
# oligodendrocyte precursor cell        112585
# central nervous system neuron          18979
# mural cell                             17865
# ependymal cell                         12559
# endothelial cell                       11070
# leukocyte                               2361
# Name: count, dtype: int64

# %%
print(adata_lr.shape)
print(adata_lr.var_names[:10])
print(adata_lr.raw is not None)
# Out:
# (2096155, 1415)
# Index(['TNFRSF18', 'SHH', 'SULT1E1', 'TENM2', 'CD200', 'C5AR2', 'VIP',
#        'IFNGR2', 'IL20', 'FZD1'],
#       dtype='object', name='gene_name')
# True

# %%
results

# %%
print(type(results))
# Out:
# <class 'NoneType'>

# %%
dir(results)
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
print(adata_lr.uns.keys())
# Out:
# dict_keys(['batch_condition', 'citation', 'genome', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title', 'uid', 'liana_res'])

# %%
res = adata_lr.uns["liana_res"]

# %%
res
# Out:
#        ligand ligand_complex  ligand_means  ligand_props receptor  \
# 19074   NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 32901   NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 19053  LRRTM4         LRRTM4      5.574590      0.997673    NRXN3
# 24307   NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 16794    NRG3           NRG3      6.055501      0.998857    ERBB4
# ...       ...            ...           ...           ...      ...
# 44467   LAMA1          LAMA1      0.162026      0.102271    ITGA1
# 43781  COL5A3         COL5A3      0.177001      0.109226   ITGA10
# 23740   HLA-A          HLA-A      0.183871      0.111605     CD8A
# 43805  COL9A2         COL9A2      0.167162      0.104589   ITGA10
# 44121   WNT8A          WNT8A      0.158459      0.105485     FZD4
#
#       receptor_complex  receptor_means  receptor_props  \
# 19074            NRXN3        6.320374        0.999692
# 32901            NRXN1        5.934241        0.999085
# 19053            NRXN3        6.320374        0.999692
# 24307            NRXN1        5.741495        0.999371
# 16794            ERBB4        5.628139        0.924143
# ...                ...             ...             ...
# 44467      ITGA1_ITGB1        0.184136        0.107909
# 43781     ITGA10_ITGB1        0.167009        0.104537
# 23740             CD8A        0.158476        0.102464
# 43805     ITGA10_ITGB1        0.167009        0.104537
# 44121        FZD4_LRP6        0.165494        0.111755
#
#                                source                          target  \
# 19074  oligodendrocyte precursor cell                GABAergic neuron
# 32901  oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 19053  oligodendrocyte precursor cell                GABAergic neuron
# 24307  oligodendrocyte precursor cell            glutamatergic neuron
# 16794                       astrocyte                GABAergic neuron
# ...                               ...                             ...
# 44467   central nervous system neuron   central nervous system neuron
# 43781   central nervous system neuron   central nervous system neuron
# 23740            glutamatergic neuron            glutamatergic neuron
# 43805   central nervous system neuron   central nervous system neuron
# 44121   central nervous system neuron   central nervous system neuron
#
#        lr_means  cellphone_pvals
# 19074  6.159640              0.0
# 32901  5.966574              0.0
# 19053  5.947482              0.0
# 24307  5.870200              0.0
# 16794  5.841820              0.0
# ...         ...              ...
# 44467  0.173081              1.0
# 43781  0.172005              1.0
# 23740  0.171174              1.0
# 43805  0.167086              1.0
# 44121  0.161976              0.0
#
# [32294 rows x 12 columns]

# %%
type(res)
# Out:
# pandas.core.frame.DataFrame

# %%
res.head()
# Out:
#        ligand ligand_complex  ligand_means  ligand_props receptor  \
# 19074   NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 32901   NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 19053  LRRTM4         LRRTM4      5.574590      0.997673    NRXN3
# 24307   NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 16794    NRG3           NRG3      6.055501      0.998857    ERBB4
#
#       receptor_complex  receptor_means  receptor_props  \
# 19074            NRXN3        6.320374        0.999692
# 32901            NRXN1        5.934241        0.999085
# 19053            NRXN3        6.320374        0.999692
# 24307            NRXN1        5.741495        0.999371
# 16794            ERBB4        5.628139        0.924143
#
#                                source                          target  \
# 19074  oligodendrocyte precursor cell                GABAergic neuron
# 32901  oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 19053  oligodendrocyte precursor cell                GABAergic neuron
# 24307  oligodendrocyte precursor cell            glutamatergic neuron
# 16794                       astrocyte                GABAergic neuron
#
#        lr_means  cellphone_pvals
# 19074  6.159640              0.0
# 32901  5.966574              0.0
# 19053  5.947482              0.0
# 24307  5.870200              0.0
# 16794  5.841820              0.0

# %%
res.to_csv("/projects/bioinformatics/DB/scRNAseq_parkinson/liana_results.csv", index=False)

# %%
liana_result = pd.read_csv("/projects/bioinformatics/DB/scRNAseq_parkinson/liana_results.csv")

# %%
liana_result.columns
# Out:
# Index(['ligand', 'ligand_complex', 'ligand_means', 'ligand_props', 'receptor',
#        'receptor_complex', 'receptor_means', 'receptor_props', 'source',
#        'target', 'lr_means', 'cellphone_pvals'],
#       dtype='object')

# %%
liana_result
# Out:
#        ligand ligand_complex  ligand_means  ligand_props receptor  \
# 0       NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 1       NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 2      LRRTM4         LRRTM4      5.574590      0.997673    NRXN3
# 3       NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 4        NRG3           NRG3      6.055501      0.998857    ERBB4
# ...       ...            ...           ...           ...      ...
# 32289   LAMA1          LAMA1      0.162026      0.102271    ITGA1
# 32290  COL5A3         COL5A3      0.177001      0.109226   ITGA10
# 32291   HLA-A          HLA-A      0.183871      0.111605     CD8A
# 32292  COL9A2         COL9A2      0.167162      0.104589   ITGA10
# 32293   WNT8A          WNT8A      0.158459      0.105485     FZD4
#
#       receptor_complex  receptor_means  receptor_props  \
# 0                NRXN3        6.320374        0.999692
# 1                NRXN1        5.934241        0.999085
# 2                NRXN3        6.320374        0.999692
# 3                NRXN1        5.741495        0.999371
# 4                ERBB4        5.628139        0.924143
# ...                ...             ...             ...
# 32289      ITGA1_ITGB1        0.184136        0.107909
# 32290     ITGA10_ITGB1        0.167009        0.104537
# 32291             CD8A        0.158476        0.102464
# 32292     ITGA10_ITGB1        0.167009        0.104537
# 32293        FZD4_LRP6        0.165494        0.111755
#
#                                source                          target  \
# 0      oligodendrocyte precursor cell                GABAergic neuron
# 1      oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 2      oligodendrocyte precursor cell                GABAergic neuron
# 3      oligodendrocyte precursor cell            glutamatergic neuron
# 4                           astrocyte                GABAergic neuron
# ...                               ...                             ...
# 32289   central nervous system neuron   central nervous system neuron
# 32290   central nervous system neuron   central nervous system neuron
# 32291            glutamatergic neuron            glutamatergic neuron
# 32292   central nervous system neuron   central nervous system neuron
# 32293   central nervous system neuron   central nervous system neuron
#
#        lr_means  cellphone_pvals
# 0      6.159640              0.0
# 1      5.966574              0.0
# 2      5.947482              0.0
# 3      5.870200              0.0
# 4      5.841820              0.0
# ...         ...              ...
# 32289  0.173081              1.0
# 32290  0.172005              1.0
# 32291  0.171174              1.0
# 32292  0.167086              1.0
# 32293  0.161976              0.0
#
# [32294 rows x 12 columns]

# %%
# apply FDR correction
liana_result["cellphone_fdr"] = false_discovery_control(
    liana_result["cellphone_pvals"].values,
    method="bh"
    
)

# %%
liana_result
# Out:
#        ligand ligand_complex  ligand_means  ligand_props receptor  \
# 0       NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 1       NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 2      LRRTM4         LRRTM4      5.574590      0.997673    NRXN3
# 3       NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 4        NRG3           NRG3      6.055501      0.998857    ERBB4
# ...       ...            ...           ...           ...      ...
# 32289   LAMA1          LAMA1      0.162026      0.102271    ITGA1
# 32290  COL5A3         COL5A3      0.177001      0.109226   ITGA10
# 32291   HLA-A          HLA-A      0.183871      0.111605     CD8A
# 32292  COL9A2         COL9A2      0.167162      0.104589   ITGA10
# 32293   WNT8A          WNT8A      0.158459      0.105485     FZD4
#
#       receptor_complex  receptor_means  receptor_props  \
# 0                NRXN3        6.320374        0.999692
# 1                NRXN1        5.934241        0.999085
# 2                NRXN3        6.320374        0.999692
# 3                NRXN1        5.741495        0.999371
# 4                ERBB4        5.628139        0.924143
# ...                ...             ...             ...
# 32289      ITGA1_ITGB1        0.184136        0.107909
# 32290     ITGA10_ITGB1        0.167009        0.104537
# 32291             CD8A        0.158476        0.102464
# 32292     ITGA10_ITGB1        0.167009        0.104537
# 32293        FZD4_LRP6        0.165494        0.111755
#
#                                source                          target  \
# 0      oligodendrocyte precursor cell                GABAergic neuron
# 1      oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 2      oligodendrocyte precursor cell                GABAergic neuron
# 3      oligodendrocyte precursor cell            glutamatergic neuron
# 4                           astrocyte                GABAergic neuron
# ...                               ...                             ...
# 32289   central nervous system neuron   central nervous system neuron
# 32290   central nervous system neuron   central nervous system neuron
# 32291            glutamatergic neuron            glutamatergic neuron
# 32292   central nervous system neuron   central nervous system neuron
# 32293   central nervous system neuron   central nervous system neuron
#
#        lr_means  cellphone_pvals  cellphone_fdr
# 0      6.159640              0.0            0.0
# 1      5.966574              0.0            0.0
# 2      5.947482              0.0            0.0
# 3      5.870200              0.0            0.0
# 4      5.841820              0.0            0.0
# ...         ...              ...            ...
# 32289  0.173081              1.0            1.0
# 32290  0.172005              1.0            1.0
# 32291  0.171174              1.0            1.0
# 32292  0.167086              1.0            1.0
# 32293  0.161976              0.0            0.0
#
# [32294 rows x 13 columns]

# %%
# filter properly

significant_lr = liana_result[
    (liana_result["cellphone_fdr"] < 0.05) &
    (liana_result["ligand_props"] > 0.1) &
    (liana_result["receptor_props"] > 0.1)
]

# %%
significant_lr
# Out:
#         ligand ligand_complex  ligand_means  ligand_props receptor  \
# 0        NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 1        NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 2       LRRTM4         LRRTM4      5.574590      0.997673    NRXN3
# 3        NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 4         NRG3           NRG3      6.055501      0.998857    ERBB4
# ...        ...            ...           ...           ...      ...
# 32281  COL15A1        COL15A1      0.191443      0.111966   ITGA10
# 32284      PYY            PYY      0.170333      0.112440    NPY5R
# 32285    WNT8A          WNT8A      0.158459      0.105485    SFRP1
# 32287    WNT8A          WNT8A      0.158459      0.105485     FRZB
# 32293    WNT8A          WNT8A      0.158459      0.105485     FZD4
#
#       receptor_complex  receptor_means  receptor_props  \
# 0                NRXN3        6.320374        0.999692
# 1                NRXN1        5.934241        0.999085
# 2                NRXN3        6.320374        0.999692
# 3                NRXN1        5.741495        0.999371
# 4                ERBB4        5.628139        0.924143
# ...                ...             ...             ...
# 32281     ITGA10_ITGB1        0.167009        0.104537
# 32284            NPY5R        0.184507        0.115443
# 32285            SFRP1        0.196252        0.107329
# 32287             FRZB        0.192638        0.116761
# 32293        FZD4_LRP6        0.165494        0.111755
#
#                                source                          target  \
# 0      oligodendrocyte precursor cell                GABAergic neuron
# 1      oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 2      oligodendrocyte precursor cell                GABAergic neuron
# 3      oligodendrocyte precursor cell            glutamatergic neuron
# 4                           astrocyte                GABAergic neuron
# ...                               ...                             ...
# 32281   central nervous system neuron   central nervous system neuron
# 32284   central nervous system neuron   central nervous system neuron
# 32285   central nervous system neuron   central nervous system neuron
# 32287   central nervous system neuron   central nervous system neuron
# 32293   central nervous system neuron   central nervous system neuron
#
#        lr_means  cellphone_pvals  cellphone_fdr
# 0      6.159640              0.0            0.0
# 1      5.966574              0.0            0.0
# 2      5.947482              0.0            0.0
# 3      5.870200              0.0            0.0
# 4      5.841820              0.0            0.0
# ...         ...              ...            ...
# 32281  0.179226              0.0            0.0
# 32284  0.177420              0.0            0.0
# 32285  0.177355              0.0            0.0
# 32287  0.175548              0.0            0.0
# 32293  0.161976              0.0            0.0
#
# [21755 rows x 13 columns]

# %%
import numpy as np

df["score"] = -np.log10(df["cellphone_pvals"] + 1e-10) * df["lr_means"]

matrix = df.groupby(["source", "target"])["score"].mean().unstack(fill_value=0)

# %%
df = significant_lr.copy()

# create interaction strength
df["score"] = df["lr_means"]  # or -np.log10(df["cellphone_fdr"])

# pivot to cell-cell matrix
cc_matrix = df.pivot_table(
    index="source",
    columns="target",
    values="score",
    aggfunc="mean"
)

# %%
cc_matrix = cc_matrix.fillna(0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.clustermap(
    cc_matrix,
    cmap="viridis",
    figsize=(10, 8),
    standard_scale=0  # important: row-wise normalization
)

plt.show()

# %%
sns.clustermap(
    cc_matrix,
    cmap="coolwarm",
    figsize=(12, 10),
    linewidths=0.5
)

# %%
cell_pairs = res.groupby(["source", "target"]).size().reset_index(name="n_interactions")

cell_pairs.sort_values("n_interactions", ascending=False).head(10)
# Out:
#                            source                         target  \
# 36  central nervous system neuron  central nervous system neuron
# 39  central nervous system neuron           glutamatergic neuron
# 33  central nervous system neuron               GABAergic neuron
# 38  central nervous system neuron                 ependymal cell
# 69           glutamatergic neuron  central nervous system neuron
# 41  central nervous system neuron                     mural cell
# 3                GABAergic neuron  central nervous system neuron
# 72           glutamatergic neuron           glutamatergic neuron
# 34  central nervous system neuron                      astrocyte
# 6                GABAergic neuron           glutamatergic neuron
#
#     n_interactions
# 36             582
# 39             561
# 33             523
# 38             514
# 69             495
# 41             494
# 3              485
# 72             484
# 34             478
# 6              472

# %%
# top ligand-receptor 

top_lr = res.groupby(["ligand", "receptor"]).size().reset_index(name="count")

top_lr.sort_values("count", ascending=False).head(20)
# Out:
#       ligand receptor  count
# 1002  SEMA3C     NRP2    138
# 602     GLUL     GRM5    121
# 600     GLUL     GRM3    121
# 97     CADM1    CADM1    121
# 98     CADM1  NECTIN3    121
# 519    EPRS1     GRM5    121
# 683     JAM3     JAM3    121
# 1072   TENM2   ADGRL3    121
# 149    CNTN1    NRCAM    121
# 866    NCAM1    NCAM2    121
# 603     GLUL     GRM7    121
# 832   LRPAP1    SORT1    121
# 876    NLGN1    NRXN1    121
# 892     NRG3    ERBB4    121
# 878    NLGN1    NRXN3    121
# 861    NAMPT     INSR    121
# 850   LRRTM4    NRXN3    121
# 138   CLSTN1    NRXN3    121
# 136   CLSTN1    NRXN1    121
# 1060    SPP1    ITGB1    121

# %%
res.columns
# Out:
# Index(['ligand', 'ligand_complex', 'ligand_means', 'ligand_props', 'receptor',
#        'receptor_complex', 'receptor_means', 'receptor_props', 'source',
#        'target', 'lr_means', 'cellphone_pvals'],
#       dtype='object')

# %%
res["cellphone_pvals"].describe()
# Out:
# count    32294.000000
# mean         0.320810
# std          0.465022
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: cellphone_pvals, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

heatmap = cell_pairs.pivot(
    index="source",
    columns="target",
    values="n_interactions"
).fillna(0)

plt.figure(figsize=(10,8))
plt.imshow(heatmap)
plt.xticks(range(len(heatmap.columns)), heatmap.columns, rotation=90)
plt.yticks(range(len(heatmap.index)), heatmap.index)
plt.title("Cell–Cell Communication Network")
plt.colorbar()
plt.show()

# %%
sig = res[res["cellphone_pvals"] < 0.05].copy()

print("Significant interactions:", sig.shape)
# Out:
# Significant interactions: (21780, 12)

# %%
# strongest interaction
sig_sorted = sig.sort_values("lr_means", ascending=False)

sig_sorted.head(20)
# Out:
#        ligand ligand_complex  ligand_means  ligand_props receptor  \
# 19074   NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 32901   NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 19053  LRRTM4         LRRTM4      5.574590      0.997673    NRXN3
# 24307   NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 16794    NRG3           NRG3      6.055501      0.998857    ERBB4
# 20162   NLGN1          NLGN1      5.268307      0.990463    NRXN3
# 32880  LRRTM4         LRRTM4      5.574590      0.997673    NRXN1
# 31331    NRG3           NRG3      6.055501      0.998857    ERBB4
# 17618    NRG3           NRG3      5.827182      0.999344    ERBB4
# 18220    NRG3           NRG3      5.798002      0.999282    ERBB4
# 24309   NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 9786     NRG3           NRG3      6.055501      0.998857    ERBB4
# 18207  LRRTM4         LRRTM4      5.040512      0.961196    NRXN3
# 24286  LRRTM4         LRRTM4      5.574590      0.997673    NRXN1
# 42729   NLGN1          NLGN1      5.998906      0.999272    NRXN3
# 31863    NRG3           NRG3      5.827182      0.999344    ERBB4
# 32263    NRG3           NRG3      5.798002      0.999282    ERBB4
# 11844   NLGN1          NLGN1      5.998906      0.999272    NRXN1
# 33582   NLGN1          NLGN1      5.268307      0.990463    NRXN1
# 42727   NLGN1          NLGN1      5.998906      0.999272    NRXN1
#
#       receptor_complex  receptor_means  receptor_props  \
# 19074            NRXN3        6.320374        0.999692
# 32901            NRXN1        5.934241        0.999085
# 19053            NRXN3        6.320374        0.999692
# 24307            NRXN1        5.741495        0.999371
# 16794            ERBB4        5.628139        0.924143
# 20162            NRXN3        6.320374        0.999692
# 32880            NRXN1        5.934241        0.999085
# 31331            ERBB4        5.433476        0.997486
# 17618            ERBB4        5.628139        0.924143
# 18220            ERBB4        5.628139        0.924143
# 24309            NRXN3        5.405705        0.992033
# 9786             ERBB4        5.336329        0.989044
# 18207            NRXN3        6.320374        0.999692
# 24286            NRXN1        5.741495        0.999371
# 42729            NRXN3        5.299519        0.961484
# 31863            ERBB4        5.433476        0.997486
# 32263            ERBB4        5.433476        0.997486
# 11844            NRXN1        5.210833        0.939161
# 33582            NRXN1        5.934241        0.999085
# 42727            NRXN1        5.191057        0.992202
#
#                                source                          target  \
# 19074  oligodendrocyte precursor cell                GABAergic neuron
# 32901  oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 19053  oligodendrocyte precursor cell                GABAergic neuron
# 24307  oligodendrocyte precursor cell            glutamatergic neuron
# 16794                       astrocyte                GABAergic neuron
# 20162   central nervous system neuron                GABAergic neuron
# 32880  oligodendrocyte precursor cell  oligodendrocyte precursor cell
# 31331                       astrocyte  oligodendrocyte precursor cell
# 17618                GABAergic neuron                GABAergic neuron
# 18220            glutamatergic neuron                GABAergic neuron
# 24309  oligodendrocyte precursor cell            glutamatergic neuron
# 9786                        astrocyte                       astrocyte
# 18207            glutamatergic neuron                GABAergic neuron
# 24286  oligodendrocyte precursor cell            glutamatergic neuron
# 42729  oligodendrocyte precursor cell   central nervous system neuron
# 31863                GABAergic neuron  oligodendrocyte precursor cell
# 32263            glutamatergic neuron  oligodendrocyte precursor cell
# 11844  oligodendrocyte precursor cell                       astrocyte
# 33582   central nervous system neuron  oligodendrocyte precursor cell
# 42727  oligodendrocyte precursor cell   central nervous system neuron
#
#        lr_means  cellphone_pvals
# 19074  6.159640              0.0
# 32901  5.966574              0.0
# 19053  5.947482              0.0
# 24307  5.870200              0.0
# 16794  5.841820              0.0
# 20162  5.794341              0.0
# 32880  5.754416              0.0
# 31331  5.744489              0.0
# 17618  5.727661              0.0
# 18220  5.713071              0.0
# 24309  5.702306              0.0
# 9786   5.695915              0.0
# 18207  5.680443              0.0
# 24286  5.658042              0.0
# 42729  5.649213              0.0
# 31863  5.630329              0.0
# 32263  5.615739              0.0
# 11844  5.604870              0.0
# 33582  5.601274              0.0
# 42727  5.594981              0.0

# %%
# group them 

pathway_summary = sig.groupby(["ligand", "receptor"]).size().reset_index(name="count")
pathway_summary.sort_values("count", ascending=False).head(10)
# Out:
#        ligand receptor  count
# 70       BMP6   ACVR2A     98
# 1198    WNT5B     FZD6     96
# 1079    TGFB1   TGFBR3     87
# 149     CNTN1    NRCAM     85
# 71       BMP6   ACVR2B     85
# 69       BMP6    ACVR1     85
# 1129  UBASH3B    PPARA     81
# 853     MPZL1    MPZL1     81
# 843    LRRTM4    NRXN1     79
# 987    SEMA3A     NRP1     79

# %%
# focus on specific 

synaptic = sig[
    sig["ligand"].str.contains("NLGN|LRRTM|NRG|CADM|NCAM")
]

# %%
# who is sending and who is receiving 
sig.groupby(["source", "target"]).size().sort_values(ascending=False).head(10)
# Out:
# source                         target
# central nervous system neuron  central nervous system neuron    439
#                                glutamatergic neuron             412
#                                GABAergic neuron                 387
# glutamatergic neuron           central nervous system neuron    376
#                                glutamatergic neuron             361
# GABAergic neuron               central nervous system neuron    360
# central nervous system neuron  astrocyte                        359
# GABAergic neuron               glutamatergic neuron             349
# mural cell                     central nervous system neuron    339
# glutamatergic neuron           GABAergic neuron                 336
# dtype: int64

# %%
 G = nx.from_pandas_edgelist(

    cell_pairs,

    source="source",

    target="target",

    edge_attr="n",

    create_using=nx.DiGraph()

)


plt.figure(figsize=(10,10))


pos = nx.spring_layout(G, k=0.5)


edges = G.edges()

weights = [G[u][v]['n'] for u,v in edges]


nx.draw(

    G, pos,

    with_labels=True,

    node_size=3000,

    font_size=8,

    width=[w/50 for w in weights]  # scale thickness

)


plt.title("Cell–Cell Communication Network")

plt.show()

# %%
sender_strength = cell_pairs.groupby("source")["n"].sum().sort_values(ascending=False)

sender_strength.plot(kind="bar", figsize=(8,4), title="Signal Senders")
plt.ylabel("Total interactions")
plt.xticks(rotation=45)
plt.show()

# %%
receiver_strength = cell_pairs.groupby("target")["n"].sum().sort_values(ascending=False)

receiver_strength.plot(kind="bar", figsize=(8,4), title="Signal Receivers")
plt.ylabel("Total interactions")
plt.xticks(rotation=45)
plt.show()
