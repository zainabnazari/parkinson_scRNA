# %%
import os
import scanpy as sc
import anndata as ad
import pandas as pd
from sklearn.metrics import normalized_mutual_info_score

# %%
# --------------------------------------------------
# 1️⃣ LOAD SAVED ANNDATA
# --------------------------------------------------

import scanpy as sc
import pandas as pd
import numpy as np
import os
from sklearn.metrics import normalized_mutual_info_score

adata = sc.read("/home/znazari/scRNAseq_parkinson/result/adata_geneformer_leiden_sweep.h5ad")
print("Loaded:", adata.shape)

# --------------------------------------------------
# 2️⃣ VERIFY METADATA EXISTS
# --------------------------------------------------

required_cols = ["disease", "cell_type"]
missing = [c for c in required_cols if c not in adata.obs.columns]

if len(missing) > 0:
    raise ValueError(f"Missing metadata columns: {missing}")

print("Metadata already present.")

# --------------------------------------------------
# 3️⃣ CREATE celltype_condition
# --------------------------------------------------

adata.obs["celltype_condition"] = (
    adata.obs["cell_type"].astype(str) + "_" +
    adata.obs["disease"].astype(str)
)

# --------------------------------------------------
# 4️⃣ FIND LEIDEN COLUMNS
# --------------------------------------------------

leiden_cols = [c for c in adata.obs.columns if c.startswith("leiden")]
print("Found clustering columns:", leiden_cols)

# --------------------------------------------------
# 5️⃣ COMPUTE PER-CELLTYPE NMI
# --------------------------------------------------

results = []

unique_classes = adata.obs["celltype_condition"].dropna().unique()

for cluster_key in leiden_cols:

    res = float(cluster_key.replace("leiden_r", ""))

    print(f"Processing resolution {res}")

    valid = adata.obs[[cluster_key, "celltype_condition"]].dropna()
    clusters = valid[cluster_key].astype(str)
    labels = valid["celltype_condition"].astype(str)

    for ct in unique_classes:
        binary_label = (labels == ct).astype(int)
        nmi_ct = normalized_mutual_info_score(clusters, binary_label)

        results.append({
            "resolution": res,
            "celltype_condition": ct,
            "NMI": nmi_ct
        })

nmi_df = pd.DataFrame(results)

print("NMI computation Done.")

# --------------------------------------------------
# 6️⃣ CREATE SORTED PIVOT (ONLY OUTPUT)
# --------------------------------------------------

pivot = nmi_df.pivot(
    index="celltype_condition",
    columns="resolution",
    values="NMI"
)

lowest_resolution = sorted(pivot.columns)[0]

sorted_pivot = pivot.sort_values(by=lowest_resolution, ascending=False)

output_path = "/home/znazari/scRNAseq_parkinson/result/nmi_table_pivot_geneformer.csv"
sorted_pivot.to_csv(output_path, index=True)

print("Final sorted pivot saved at:", output_path)
# Out:
# Loaded: (2096155, 512)
# Metadata already present.
# Found clustering columns: ['leiden_r0.3', 'leiden_r0.5', 'leiden_r0.8', 'leiden_r1.0']
# Processing resolution 0.3
# Processing resolution 0.5
# Processing resolution 0.8
# Processing resolution 1.0
# NMI computation Done.
# Final sorted pivot saved at: /home/znazari/scRNAseq_parkinson/result/nmi_table_pivot_geneformer.csv

# %%
sorted_pivot
# Out:
# resolution                                               0.3       0.5  \
# celltype_condition
# oligodendrocyte_Parkinson disease                   0.302496  0.297744
# glutamatergic neuron_Parkinson disease              0.234966  0.230851
# astrocyte_Parkinson disease                         0.206457  0.202512
# central nervous system macrophage_Parkinson dis...  0.150838  0.147172
# GABAergic neuron_Parkinson disease                  0.149142  0.146907
# oligodendrocyte precursor cell_Parkinson disease    0.138134  0.133466
# glutamatergic neuron_normal                         0.067887  0.066745
# oligodendrocyte_normal                              0.066178  0.065118
# GABAergic neuron_normal                             0.042551  0.041877
# astrocyte_normal                                    0.040826  0.039882
# oligodendrocyte precursor cell_normal               0.034590  0.033386
# mural cell_Parkinson disease                        0.034529  0.033636
# central nervous system macrophage_normal            0.031267  0.030469
# ependymal cell_Parkinson disease                    0.027672  0.026960
# endothelial cell_Parkinson disease                  0.024258  0.023621
# central nervous system neuron_Parkinson disease     0.017091  0.016772
# mural cell_normal                                   0.010165  0.009896
# endothelial cell_normal                             0.006546  0.006372
# leukocyte_Parkinson disease                         0.006072  0.005912
# ependymal cell_normal                               0.004768  0.004660
# central nervous system neuron_normal                0.004499  0.004398
# leukocyte_normal                                    0.002117  0.002061
#
# resolution                                               0.8       1.0
# celltype_condition
# oligodendrocyte_Parkinson disease                   0.257849  0.242669
# glutamatergic neuron_Parkinson disease              0.195522  0.182944
# astrocyte_Parkinson disease                         0.170571  0.159047
# central nervous system macrophage_Parkinson dis...  0.123078  0.114536
# GABAergic neuron_Parkinson disease                  0.124583  0.116017
# oligodendrocyte precursor cell_Parkinson disease    0.111505  0.103748
# glutamatergic neuron_normal                         0.055728  0.051969
# oligodendrocyte_normal                              0.056427  0.052798
# GABAergic neuron_normal                             0.035038  0.032507
# astrocyte_normal                                    0.033082  0.030677
# oligodendrocyte precursor cell_normal               0.027637  0.025635
# mural cell_Parkinson disease                        0.027805  0.025768
# central nervous system macrophage_normal            0.025223  0.023388
# ependymal cell_Parkinson disease                    0.023045  0.021349
# endothelial cell_Parkinson disease                  0.019500  0.018064
# central nervous system neuron_Parkinson disease     0.016624  0.015455
# mural cell_normal                                   0.008161  0.007557
# endothelial cell_normal                             0.005253  0.004863
# leukocyte_Parkinson disease                         0.004873  0.004512
# ependymal cell_normal                               0.004021  0.003721
# central nervous system neuron_normal                0.003719  0.003429
# leukocyte_normal                                    0.001698  0.001572

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sorted_pivot = pd.read_csv("/home/znazari/scRNAseq_parkinson/result/nmi_table_pivot_geneformer.csv", index_col=0)
plt.figure(figsize=(8,6))
sns.heatmap(sorted_pivot, annot=True, cmap="viridis")
plt.title("NMI per celltype_condition (Geneformer)")
plt.xlabel("Leiden resolution")
plt.ylabel("Celltype + Disease")
plt.tight_layout()
plt.show()
